# %% [markdown]
# <a href="https://colab.research.google.com/github/NafisFuadTanvir/Ai-lab-works/blob/main/leniar_regressionbaseon_insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset= pd.read_csv("/content/insurance (1).csv")
dataset.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       1  16884.92400
# 1   18    0  33.770         1       0       2   1725.55230
# 2   28    0  33.000         3       0       2   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,1].values

# %%
dataset.sex[dataset.sex == 'male'] = 0
dataset.sex[dataset.sex == 'female'] = 1
print(dataset)
# Out:
#       age sex     bmi  children smoker     region      charges
# 0      19   1  27.900         0    yes  southwest  16884.92400
# 1      18   0  33.770         1     no  southeast   1725.55230
# 2      28   0  33.000         3     no  southeast   4449.46200
# 3      33   0  22.705         0     no  northwest  21984.47061
# 4      32   0  28.880         0     no  northwest   3866.85520
# ...   ...  ..     ...       ...    ...        ...          ...
# 1333   50   0  30.970         3     no  northwest  10600.54830
# 1334   18   1  31.920         0     no  northeast   2205.98080
# 1335   18   1  36.850         0     no  southeast   1629.83350
# 1336   21   1  25.800         0     no  southwest   2007.94500
# 1337   61   1  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
# <ipython-input-21-a57716490899>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataset.smoker[dataset.smoker == 'yes'] = 1
dataset.smoker[dataset.smoker == 'no'] = 0
print(dataset)
# Out:
#       age sex     bmi  children smoker     region      charges
# 0      19   1  27.900         0      1  southwest  16884.92400
# 1      18   0  33.770         1      0  southeast   1725.55230
# 2      28   0  33.000         3      0  southeast   4449.46200
# 3      33   0  22.705         0      0  northwest  21984.47061
# 4      32   0  28.880         0      0  northwest   3866.85520
# ...   ...  ..     ...       ...    ...        ...          ...
# 1333   50   0  30.970         3      0  northwest  10600.54830
# 1334   18   1  31.920         0      0  northeast   2205.98080
# 1335   18   1  36.850         0      0  southeast   1629.83350
# 1336   21   1  25.800         0      0  southwest   2007.94500
# 1337   61   1  29.070         0      1  northwest  29141.36030
#
# [1338 rows x 7 columns]
# <ipython-input-22-a3a227de4936>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataset.region[dataset.region == 'southeast'] = 1
dataset.region[dataset.region == 'southwest'] = 2
dataset.region[dataset.region == 'northeast'] = 3
dataset.region[dataset.region == 'northwest'] = 4
print(dataset)
# Out:
#       age sex     bmi  children smoker region      charges
# 0      19   1  27.900         0      1      2  16884.92400
# 1      18   0  33.770         1      0      1   1725.55230
# 2      28   0  33.000         3      0      1   4449.46200
# 3      33   0  22.705         0      0      4  21984.47061
# 4      32   0  28.880         0      0      4   3866.85520
# ...   ...  ..     ...       ...    ...    ...          ...
# 1333   50   0  30.970         3      0      4  10600.54830
# 1334   18   1  31.920         0      0      3   2205.98080
# 1335   18   1  36.850         0      0      1   1629.83350
# 1336   21   1  25.800         0      0      2   2007.94500
# 1337   61   1  29.070         0      1      4  29141.36030
#
# [1338 rows x 7 columns]
# <ipython-input-23-a404297c480d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 1.1102230246251565e-16
# [-1.37686674e-17  1.00000000e+00  0.00000000e+00 -1.94289029e-16
#  -1.66533454e-16  2.08166817e-16]

# %%
y_pred=regressor.predict(X_test)
df=pd.DataFrame({"Actual":Y_test,"predictad":y_pred})
df.head()
# Out:
#    Actual     predictad
# 0       0 -5.910706e-16
# 1       1  1.000000e+00
# 2       0 -4.804848e-16
# 3       0 -1.043660e-16
# 4       1  1.000000e+00

# %%
from sklearn import metrics
print("Mean square error:",metrics.mean_squared_error(Y_test,y_pred))
# Out:
# Mean square error: 1.7858245182416963e-31
